# %%
# 표본상관계수(피어슨 상관계수)
from sklearn.datasets import load_iris
X = load_iris().data
x1 = X[:, 0] # 꽃받침 길이
x2 = X[:, 1] # 꽃받침 폭
x3 = X[:, 2] # 꽃잎 길이
x4 = X[:, 3] # 꽃잎 폭
sp.stats.pearsonr(x1, x3)[0] # 상관계수만을 뽑아내기 위해. 유의확률은 제거
# Out:
# 0.8717537758865832

# %%
import scipy as sp
import scipy.stats

rv = sp.stats.norm(loc = 1, scale = 2) #rv는 정규분포의 객체
xx = np.linspace(-8, 8, 100)
pdf = rv.pdf(xx)
plt.plot(xx, pdf)
plt.title("확률밀도함수")
plt.xlabel("x")
plt.ylabel("p(x)")
plt.show()
